# %%
import os
import sys
import random
import math
import numpy as np
import skimage.io
import matplotlib
import matplotlib.pyplot as plt
import cv2

# %%
#IMAGE_DIR="/Users/gosato/Desktop/GenDataForDFV/train_data_example/20200221/yes/image_03/data"
base_path='/home/ubuntu/data/result_tokushima_dataprocessing'
OUTPUT_DIR="/tmp/result"

# %%
#file_names=[f.name for f in os.scandir(IMAGE_DIR) if not f.name.startswith('.')]

# %%
file_names = []
files = open(base_path + "/train.txt" , 'r')

for file in files:
    file = file.rstrip('\n')
    file_names.append(file)

# %%
file_names
# Out:
# ['drive_sunset-4 0000000001',
#  'drive_sunset-4 0000000002',
#  'drive_sunset-4 0000000003',
#  'drive_sunset-4 0000000004',
#  'drive_sunset-4 0000000005',
#  'drive_sunset-4 0000000006',
#  'drive_sunset-4 0000000007',
#  'drive_sunset-4 0000000008',
#  'drive_sunset-4 0000000009',
#  'drive_sunset-4 0000000010',
#  'drive_sunset-4 0000000011',
#  'drive_sunset-4 0000000012',
#  'drive_sunset-4 0000000013',
#  'drive_sunset-4 0000000014',
#  'drive_sunset-4 0000000015',
#  'drive_sunset-4 0000000016',
#  'drive_sunset-4 0000000017',
#  'drive_sunset-4 0000000018',
#  'drive_sunset-4 0000000019',
#  'drive_sunset-4 0000000020',
#  'drive_sunset-4 0000000021',
#  'drive_sunset-4 0000000022',
#  'drive_sunset-4 0000000023',
#  'drive_sunset-4 0000000024',
#  'drive_sunset-4 0000000025',
#  'drive_sunset-4 0000000026',
#  'drive_sunset-4 0000000027',
#  'drive_sunset-4 0000000028',
#  'drive_sunset-4 0000000029',
#  'drive_sunset-4 0000000030',
#  'drive_sunset-4 0000000031',
#  'drive_sunset-4 0000000032',
#  'drive_sunset-4 0000000033',
#  'drive_sunset-4 0000000034',
#  'drive_sunset-4 0000000035',
#  'drive_sunset-4 0000000036',
#  'drive_sunset-4 0000000037',
#  'drive_sunset-4 0000000038',
#  'drive_sunset-4 0000000039',
#  'drive_sunset-4 0000000040',
#  'drive_sunset-4 0000000041',
#  'drive_sunset-4 0000000042',
#  'drive_sunset-4 0000000043',
#  'drive_sunset-4 0000000044',
#  'drive_sunset-4 0000000045',
#  'drive_sunset-4 0000000046',
#  'drive_sunset-4 0000000047',
#  'drive_sunset-4 0000000048',
#  'drive_sunset-4 0000000049',
#  'drive_sunset-4 0000000050',
#  'drive_sunset-4 0000000051',
#  'drive_sunset-4 0000000052',
#  'drive_sunset-4 0000000053',
#  'drive_sunset-4 0000000054',
#  'drive_sunset-4 0000000055',
#  'drive_sunset-4 0000000056',
#  'drive_sunset-4 0000000057',
#  'drive_sunset-4 0000000058',
#  'drive_sunset-4 0000000059',
#  'drive_sunset-4 0000000060',
#  'drive_sunset-4 0000000061',
#  'drive_sunset-4 0000000062',
#  'drive_sunset-4 0000000063',
#  'drive_sunset-4 0000000064',
#  'drive_sunset-4 0000000065',
#  'drive_sunset-4 0000000066',
#  'drive_sunset-4 0000000067',
#  'drive_sunset-4 0000000068',
#  'drive_sunset-4 0000000069',
#  'drive_sunset-4 0000000070',
#  'drive_sunset-4 0000000071',
#  'drive_sunset-4 0000000072',
#  'drive_sunset-4 0000000073',
#  'drive_sunset-4 0000000074',
#  'drive_sunset-4 0000000075',
#  'drive_sunset-4 0000000076',
#  'drive_sunset-4 0000000077',
#  'drive_sunset-4 0000000078',
#  'drive_sunset-4 0000000079',
#  'drive_sunset-4 0000000080',
#  'drive_sunset-4 0000000081',
#  'drive_sunset-4 0000000082',
#  'drive_sunset-4 0000000083',
#  'drive_sunset-4 0000000084',
#  'drive_sunset-4 0000000085',
#  'drive_sunset-4 0000000086',
#  'drive_sunset-4 0000000087',
#  'drive_sunset-4 0000000088',
#  'drive_sunset-4 0000000089',
#  'drive_sunset-4 0000000090',
#  'drive_sunset-4 0000000091',
#  'drive_sunset-4 0000000092',
#  'drive_sunset-4 0000000093',
#  'drive_sunset-4 0000000094',
#  'drive_sunset-4 0000000095',
#  'drive_sunset-4 0000000096',
#  'drive_sunset-4 0000000097',
#  'drive_sunset-4 0000000098',
#  'drive_sunset-4 0000000099',
#  'drive_sunset-4 0000000100',
#  'drive_sunset-4 0000000101',
#  'drive_sunset-4 0000000102',
#  'drive_sunset-4 0000000103',
#  'drive_sunset-4 0000000104',
#  'drive_sunset-4 0000000105',
#  'drive_sunset-4 0000000106',
#  'drive_sunset-4 0000000107',
#  'drive_sunset-4 0000000108',
#  'drive_sunset-4 0000000109',
#  'drive_sunset-4 0000000110',
#  'drive_sunset-4 0000000111',
#  'drive_sunset-4 0000000112',
#  'drive_sunset-4 0000000113',
#  'drive_sunset-4 0000000114',
#  'drive_sunset-4 0000000115',
#  'drive_sunset-4 0000000116',
#  'drive_sunset-4 0000000117',
#  'drive_sunset-4 0000000118',
#  'drive_noon-3 0000000001',
#  'drive_noon-3 0000000002',
#  'drive_noon-3 0000000003',
#  'drive_noon-3 0000000004',
#  'drive_noon-3 0000000005',
#  'drive_noon-3 0000000006',
#  'drive_noon-3 0000000007',
#  'drive_noon-3 0000000008',
#  'drive_noon-3 0000000009',
#  'drive_noon-3 0000000010',
#  'drive_noon-3 0000000011',
#  'drive_noon-3 0000000012',
#  'drive_noon-3 0000000013',
#  'drive_noon-3 0000000014',
#  'drive_noon-3 0000000015',
#  'drive_noon-3 0000000016',
#  'drive_noon-3 0000000017',
#  'drive_noon-3 0000000018',
#  'drive_noon-3 0000000019',
#  'drive_noon-3 0000000020',
#  'drive_noon-3 0000000021',
#  'drive_noon-3 0000000022',
#  'drive_noon-3 0000000023',
#  'drive_noon-3 0000000024',
#  'drive_noon-3 0000000025',
#  'drive_noon-3 0000000026',
#  'drive_noon-3 0000000027',
#  'drive_noon-3 0000000028',
#  'drive_noon-3 0000000029',
#  'drive_noon-3 0000000030',
#  'drive_noon-3 0000000031',
#  'drive_noon-3 0000000032',
#  'drive_noon-3 0000000033',
#  'drive_noon-3 0000000034',
#  'drive_noon-3 0000000035',
#  'drive_noon-3 0000000036',
#  'drive_noon-3 0000000037',
#  'drive_noon-3 0000000038',
#  'drive_noon-3 0000000039',
#  'drive_noon-3 0000000040',
#  'drive_noon-3 0000000041',
#  'drive_noon-3 0000000042',
#  'drive_noon-3 0000000043',
#  'drive_noon-3 0000000044',
#  'drive_noon-3 0000000045',
#  'drive_noon-3 0000000046',
#  'drive_noon-3 0000000047',
#  'drive_noon-3 0000000048',
#  'drive_noon-3 0000000049',
#  'drive_noon-3 0000000050',
#  'drive_noon-3 0000000051',
#  'drive_noon-3 0000000052',
#  'drive_noon-3 0000000053',
#  'drive_noon-3 0000000054',
#  'drive_noon-3 0000000055',
#  'drive_noon-3 0000000056',
#  'drive_noon-3 0000000057',
#  'drive_noon-3 0000000058',
#  'drive_noon-3 0000000059',
#  'drive_noon-3 0000000060',
#  'drive_noon-3 0000000061',
#  'drive_noon-3 0000000062',
#  'drive_noon-3 0000000063',
#  'drive_noon-3 0000000064',
#  'drive_noon-3 0000000065',
#  'drive_noon-3 0000000066',
#  'drive_noon-3 0000000067',
#  'drive_noon-3 0000000068',
#  'drive_noon-3 0000000069',
#  'drive_noon-3 0000000070',
#  'drive_noon-3 0000000071',
#  'drive_noon-3 0000000072',
#  'drive_noon-3 0000000073',
#  'drive_noon-3 0000000074',
#  'drive_noon-3 0000000075',
#  'drive_noon-3 0000000076',
#  'drive_noon-3 0000000077',
#  'drive_noon-3 0000000078',
#  'drive_noon-3 0000000079',
#  'drive_noon-3 0000000080',
#  'drive_noon-3 0000000081',
#  'drive_noon-3 0000000082',
#  'drive_noon-3 0000000083',
#  'drive_noon-3 0000000084',
#  'drive_noon-3 0000000085',
#  'drive_noon-3 0000000086',
#  'drive_noon-3 0000000087',
#  'drive_noon-3 0000000088',
#  'drive_noon-3 0000000089',
#  'drive_noon-3 0000000090',
#  'drive_noon-3 0000000091',
#  'drive_noon-3 0000000092',
#  'drive_noon-3 0000000093',
#  'drive_noon-3 0000000094',
#  'drive_noon-3 0000000095',
#  'drive_noon-3 0000000096',
#  'drive_noon-3 0000000097',
#  'drive_noon-3 0000000098',
#  'drive_noon-3 0000000099',
#  'drive_noon-3 0000000100',
#  'drive_noon-3 0000000101',
#  'drive_noon-3 0000000102',
#  'drive_noon-3 0000000103',
#  'drive_noon-3 0000000104',
#  'drive_noon-3 0000000105',
#  'drive_noon-3 0000000106',
#  'drive_noon-3 0000000107',
#  'drive_noon-3 0000000108',
#  'drive_noon-3 0000000109',
#  'drive_noon-3 0000000110',
#  'drive_noon-3 0000000111',
#  'drive_noon-3 0000000112',
#  'drive_noon-3 0000000113',
#  'drive_noon-3 0000000114',
#  'drive_noon-3 0000000115',
#  'drive_noon-3 0000000116',
#  'drive_noon-3 0000000117',
#  'drive_noon-3 0000000118',
#  'drive_noon-3 0000000001',
#  'drive_noon-3 0000000002',
#  'drive_noon-3 0000000003',
#  'drive_noon-3 0000000004',
#  'drive_noon-3 0000000005',
#  'drive_noon-3 0000000006',
#  'drive_noon-3 0000000007',
#  'drive_noon-3 0000000008',
#  'drive_noon-3 0000000009',
#  'drive_noon-3 0000000010',
#  'drive_noon-3 0000000011',
#  'drive_noon-3 0000000012',
#  'drive_noon-3 0000000013',
#  'drive_noon-3 0000000014',
#  'drive_noon-3 0000000015',
#  'drive_noon-3 0000000016',
#  'drive_noon-3 0000000017',
#  'drive_noon-3 0000000018',
#  'drive_noon-3 0000000019',
#  'drive_noon-3 0000000020',
#  'drive_noon-3 0000000021',
#  'drive_noon-3 0000000022',
#  'drive_noon-3 0000000023',
#  'drive_noon-3 0000000024',
#  'drive_noon-3 0000000025',
#  'drive_noon-3 0000000026',
#  'drive_noon-3 0000000027',
#  'drive_noon-3 0000000028',
#  'drive_noon-3 0000000029',
#  'drive_noon-3 0000000030',
#  'drive_noon-3 0000000031',
#  'drive_noon-3 0000000032',
#  'drive_noon-3 0000000033',
#  'drive_noon-3 0000000034',
#  'drive_noon-3 0000000035',
#  'drive_noon-3 0000000036',
#  'drive_noon-3 0000000037',
#  'drive_noon-3 0000000038',
#  'drive_noon-3 0000000039',
#  'drive_noon-3 0000000040',
#  'drive_noon-3 0000000041',
#  'drive_noon-3 0000000042',
#  'drive_noon-3 0000000043',
#  'drive_noon-3 0000000044',
#  'drive_noon-3 0000000045',
#  'drive_noon-3 0000000046',
#  'drive_noon-3 0000000047',
#  'drive_noon-3 0000000048',
#  'drive_noon-3 0000000049',
#  'drive_noon-3 0000000050',
#  'drive_noon-3 0000000051',
#  'drive_noon-3 0000000052',
#  'drive_noon-3 0000000053',
#  'drive_noon-3 0000000054',
#  'drive_noon-3 0000000055',
#  'drive_noon-3 0000000056',
#  'drive_noon-3 0000000057',
#  'drive_noon-3 0000000058',
#  'drive_noon-3 0000000059',
#  'drive_noon-3 0000000060',
#  'drive_noon-3 0000000061',
#  'drive_noon-3 0000000062',
#  'drive_noon-3 0000000063',
#  'drive_noon-3 0000000064',
#  'drive_noon-3 0000000065',
#  'drive_noon-3 0000000066',
#  'drive_noon-3 0000000067',
#  'drive_noon-3 0000000068',
#  'drive_noon-3 0000000069',
#  'drive_noon-3 0000000070',
#  'drive_noon-3 0000000071',
#  'drive_noon-3 0000000072',
#  'drive_noon-3 0000000073',
#  'drive_noon-3 0000000074',
#  'drive_noon-3 0000000075',
#  'drive_noon-3 0000000076',
#  'drive_noon-3 0000000077',
#  'drive_noon-3 0000000078',
#  'drive_noon-3 0000000079',
#  'drive_noon-3 0000000080',
#  'drive_noon-3 0000000081',
#  'drive_noon-3 0000000082',
#  'drive_noon-3 0000000083',
#  'drive_noon-3 0000000084',
#  'drive_noon-3 0000000085',
#  'drive_noon-3 0000000086',
#  'drive_noon-3 0000000087',
#  'drive_noon-3 0000000088',
#  'drive_noon-3 0000000089',
#  'drive_noon-3 0000000090',
#  'drive_noon-3 0000000091',
#  'drive_noon-3 0000000092',
#  'drive_noon-3 0000000093',
#  'drive_noon-3 0000000094',
#  'drive_noon-3 0000000095',
#  'drive_noon-3 0000000096',
#  'drive_noon-3 0000000097',
#  'drive_noon-3 0000000098',
#  'drive_noon-3 0000000099',
#  'drive_noon-3 0000000100',
#  'drive_noon-3 0000000101',
#  'drive_noon-3 0000000102',
#  'drive_noon-3 0000000103',
#  'drive_noon-3 0000000104',
#  'drive_noon-3 0000000105',
#  'drive_noon-3 0000000106',
#  'drive_noon-3 0000000107',
#  'drive_noon-3 0000000108',
#  'drive_sunset-3 0000000001',
#  'drive_sunset-3 0000000002',
#  'drive_sunset-3 0000000003',
#  'drive_sunset-3 0000000004',
#  'drive_sunset-3 0000000005',
#  'drive_sunset-3 0000000006',
#  'drive_sunset-3 0000000007',
#  'drive_sunset-3 0000000008',
#  'drive_sunset-3 0000000009',
#  'drive_sunset-3 0000000010',
#  'drive_sunset-3 0000000011',
#  'drive_sunset-3 0000000012',
#  'drive_sunset-3 0000000013',
#  'drive_sunset-3 0000000014',
#  'drive_sunset-3 0000000015',
#  'drive_sunset-3 0000000016',
#  'drive_sunset-3 0000000017',
#  'drive_sunset-3 0000000018',
#  'drive_sunset-3 0000000019',
#  'drive_sunset-3 0000000020',
#  'drive_sunset-3 0000000021',
#  'drive_sunset-3 0000000022',
#  'drive_sunset-3 0000000023',
#  'drive_sunset-3 0000000024',
#  'drive_sunset-3 0000000025',
#  'drive_sunset-3 0000000026',
#  'drive_sunset-3 0000000027',
#  'drive_sunset-3 0000000028',
#  'drive_sunset-3 0000000029',
#  'drive_sunset-3 0000000030',
#  'drive_sunset-3 0000000031',
#  'drive_sunset-3 0000000032',
#  'drive_sunset-3 0000000033',
#  'drive_sunset-3 0000000034',
#  'drive_sunset-3 0000000035',
#  'drive_sunset-3 0000000036',
#  'drive_sunset-3 0000000037',
#  'drive_sunset-3 0000000038',
#  'drive_sunset-3 0000000039',
#  'drive_sunset-3 0000000040',
#  'drive_sunset-3 0000000041',
#  'drive_sunset-3 0000000042',
#  'drive_sunset-3 0000000043',
#  'drive_sunset-3 0000000044',
#  'drive_sunset-3 0000000045',
#  'drive_sunset-3 0000000046',
#  'drive_sunset-3 0000000047',
#  'drive_sunset-3 0000000048',
#  'drive_sunset-3 0000000049',
#  'drive_sunset-3 0000000050',
#  'drive_sunset-3 0000000051',
#  'drive_sunset-3 0000000052',
#  'drive_sunset-3 0000000053',
#  'drive_sunset-3 0000000054',
#  'drive_sunset-3 0000000055',
#  'drive_sunset-3 0000000056',
#  'drive_sunset-3 0000000057',
#  'drive_sunset-3 0000000058',
#  'drive_sunset-3 0000000059',
#  'drive_sunset-3 0000000060',
#  'drive_sunset-3 0000000061',
#  'drive_sunset-3 0000000062',
#  'drive_sunset-3 0000000063',
#  'drive_sunset-3 0000000064',
#  'drive_sunset-3 0000000065',
#  'drive_sunset-3 0000000066',
#  'drive_sunset-3 0000000067',
#  'drive_sunset-3 0000000068',
#  'drive_sunset-3 0000000069',
#  'drive_sunset-3 0000000070',
#  'drive_sunset-3 0000000071',
#  'drive_sunset-3 0000000072',
#  'drive_sunset-3 0000000073',
#  'drive_sunset-3 0000000074',
#  'drive_sunset-3 0000000075',
#  'drive_sunset-3 0000000076',
#  'drive_sunset-3 0000000077',
#  'drive_sunset-3 0000000078',
#  'drive_sunset-3 0000000079',
#  'drive_sunset-3 0000000080',
#  'drive_sunset-3 0000000081',
#  'drive_sunset-3 0000000082',
#  'drive_sunset-3 0000000083',
#  'drive_sunset-3 0000000084',
#  'drive_sunset-3 0000000085',
#  'drive_sunset-3 0000000086',
#  'drive_sunset-3 0000000087',
#  'drive_sunset-3 0000000088',
#  'drive_sunset-3 0000000089',
#  'drive_sunset-3 0000000090',
#  'drive_sunset-3 0000000091',
#  'drive_sunset-3 0000000092',
#  'drive_sunset-3 0000000093',
#  'drive_sunset-3 0000000094',
#  'drive_sunset-3 0000000095',
#  'drive_sunset-3 0000000096',
#  'drive_sunset-3 0000000097',
#  'drive_sunset-3 0000000098',
#  'drive_sunset-3 0000000099',
#  'drive_sunset-3 0000000100',
#  'drive_sunset-3 0000000101',
#  'drive_sunset-3 0000000102',
#  'drive_sunset-3 0000000103',
#  'drive_sunset-3 0000000104',
#  'drive_sunset-3 0000000105',
#  'drive_sunset-3 0000000106',
#  'drive_sunset-3 0000000107',
#  'drive_sunset-3 0000000108',
#  'drive_sunset-3 0000000109',
#  'drive_sunset-3 0000000110',
#  'drive_sunset-3 0000000111',
#  'drive_sunset-3 0000000112',
#  'drive_sunset-3 0000000113',
#  'drive_sunset-3 0000000114',
#  'drive_sunset-3 0000000115',
#  'drive_sunset-3 0000000116',
#  'drive_sunset-3 0000000117',
#  'drive_sunset-3 0000000118',
#  'drive_sunset-3 0000000001',
#  'drive_sunset-3 0000000002',
#  'drive_sunset-3 0000000003',
#  'drive_sunset-3 0000000004',
#  'drive_sunset-3 0000000005',
#  'drive_sunset-3 0000000006',
#  'drive_sunset-3 0000000007',
#  'drive_sunset-3 0000000008',
#  'drive_sunset-3 0000000009',
#  'drive_sunset-3 0000000010',
#  'drive_sunset-3 0000000011',
#  'drive_sunset-3 0000000012',
#  'drive_sunset-3 0000000013',
#  'drive_sunset-3 0000000014',
#  'drive_sunset-3 0000000015',
#  'drive_sunset-3 0000000016',
#  'drive_sunset-3 0000000017',
#  'drive_sunset-3 0000000018',
#  'drive_sunset-3 0000000019',
#  'drive_sunset-3 0000000020',
#  'drive_sunset-3 0000000021',
#  'drive_sunset-3 0000000022',
#  'drive_sunset-3 0000000023',
#  'drive_sunset-3 0000000024',
#  'drive_sunset-3 0000000025',
#  'drive_sunset-3 0000000026',
#  'drive_sunset-3 0000000027',
#  'drive_sunset-3 0000000028',
#  'drive_sunset-3 0000000029',
#  'drive_sunset-3 0000000030',
#  'drive_sunset-3 0000000031',
#  'drive_sunset-3 0000000032',
#  'drive_sunset-3 0000000033',
#  'drive_sunset-3 0000000034',
#  'drive_sunset-3 0000000035',
#  'drive_sunset-3 0000000036',
#  'drive_sunset-3 0000000037',
#  'drive_sunset-3 0000000038',
#  'drive_sunset-3 0000000039',
#  'drive_sunset-3 0000000040',
#  'drive_sunset-3 0000000041',
#  'drive_sunset-3 0000000042',
#  'drive_sunset-3 0000000043',
#  'drive_sunset-3 0000000044',
#  'drive_sunset-3 0000000045',
#  'drive_sunset-3 0000000046',
#  'drive_sunset-3 0000000047',
#  'drive_sunset-3 0000000048',
#  'drive_sunset-3 0000000049',
#  'drive_sunset-3 0000000050',
#  'drive_sunset-3 0000000051',
#  'drive_sunset-3 0000000052',
#  'drive_sunset-3 0000000053',
#  'drive_sunset-3 0000000054',
#  'drive_sunset-3 0000000055',
#  'drive_sunset-3 0000000056',
#  'drive_sunset-3 0000000057',
#  'drive_sunset-3 0000000058',
#  'drive_sunset-3 0000000059',
#  'drive_sunset-3 0000000060',
#  'drive_sunset-3 0000000061',
#  'drive_sunset-3 0000000062',
#  'drive_sunset-3 0000000063',
#  'drive_sunset-3 0000000064',
#  'drive_sunset-3 0000000065',
#  'drive_sunset-3 0000000066',
#  'drive_sunset-3 0000000067',
#  'drive_sunset-3 0000000068',
#  'drive_sunset-3 0000000069',
#  'drive_sunset-3 0000000070',
#  'drive_sunset-3 0000000071',
#  'drive_sunset-3 0000000072',
#  'drive_sunset-3 0000000073',
#  'drive_sunset-3 0000000074',
#  'drive_sunset-3 0000000075',
#  'drive_sunset-3 0000000076',
#  'drive_sunset-3 0000000077',
#  'drive_sunset-3 0000000078',
#  'drive_sunset-3 0000000079',
#  'drive_sunset-3 0000000080',
#  'drive_sunset-3 0000000081',
#  'drive_sunset-3 0000000082',
#  'drive_sunset-3 0000000083',
#  'drive_sunset-3 0000000084',
#  'drive_sunset-3 0000000085',
#  'drive_sunset-3 0000000086',
#  'drive_sunset-3 0000000087',
#  'drive_sunset-3 0000000088',
#  'drive_sunset-3 0000000089',
#  'drive_sunset-3 0000000090',
#  'drive_sunset-3 0000000091',
#  'drive_sunset-3 0000000092',
#  'drive_sunset-3 0000000093',
#  'drive_sunset-3 0000000094',
#  'drive_sunset-3 0000000095',
#  'drive_sunset-3 0000000096',
#  'drive_sunset-3 0000000097',
#  'drive_sunset-3 0000000098',
#  'drive_sunset-3 0000000099',
#  'drive_sunset-3 0000000100',
#  'drive_sunset-3 0000000101',
#  'drive_sunset-3 0000000102',
#  'drive_sunset-3 0000000103',
#  'drive_sunset-3 0000000104',
#  'drive_sunset-3 0000000105',
#  'drive_sunset-3 0000000106',
#  'drive_sunset-3 0000000107',
#  'drive_sunset-3 0000000108',
#  'drive_sunset-3 0000000001',
#  'drive_sunset-3 0000000002',
#  'drive_sunset-3 0000000003',
#  'drive_sunset-3 0000000004',
#  'drive_sunset-3 0000000005',
#  'drive_sunset-3 0000000006',
#  'drive_sunset-3 0000000007',
#  'drive_sunset-3 0000000008',
#  'drive_sunset-3 0000000009',
#  'drive_sunset-3 0000000010',
#  'drive_sunset-3 0000000011',
#  'drive_sunset-3 0000000012',
#  'drive_sunset-3 0000000013',
#  'drive_sunset-3 0000000014',
#  'drive_sunset-3 0000000015',
#  'drive_sunset-3 0000000016',
#  'drive_sunset-3 0000000017',
#  'drive_sunset-3 0000000018',
#  'drive_sunset-3 0000000019',
#  'drive_sunset-3 0000000020',
#  'drive_sunset-3 0000000021',
#  'drive_sunset-3 0000000022',
#  'drive_sunset-3 0000000023',
#  'drive_sunset-3 0000000024',
#  'drive_sunset-3 0000000025',
#  'drive_sunset-3 0000000026',
#  'drive_sunset-3 0000000027',
#  'drive_sunset-3 0000000028',
#  'drive_sunset-3 0000000029',
#  'drive_sunset-3 0000000030',
#  'drive_sunset-3 0000000031',
#  'drive_sunset-3 0000000032',
#  'drive_sunset-3 0000000033',
#  'drive_sunset-3 0000000034',
#  'drive_sunset-3 0000000035',
#  'drive_sunset-3 0000000036',
#  'drive_sunset-3 0000000037',
#  'drive_sunset-3 0000000038',
#  'drive_sunset-3 0000000039',
#  'drive_sunset-3 0000000040',
#  'drive_sunset-3 0000000041',
#  'drive_sunset-3 0000000042',
#  'drive_sunset-3 0000000043',
#  'drive_sunset-3 0000000044',
#  'drive_sunset-3 0000000045',
#  'drive_sunset-3 0000000046',
#  'drive_sunset-3 0000000047',
#  'drive_sunset-3 0000000048',
#  'drive_sunset-3 0000000049',
#  'drive_sunset-3 0000000050',
#  'drive_sunset-3 0000000051',
#  'drive_sunset-3 0000000052',
#  'drive_sunset-3 0000000053',
#  'drive_sunset-3 0000000054',
#  'drive_sunset-3 0000000055',
#  'drive_sunset-3 0000000056',
#  'drive_sunset-3 0000000057',
#  'drive_sunset-3 0000000058',
#  'drive_sunset-3 0000000059',
#  'drive_sunset-3 0000000060',
#  'drive_sunset-3 0000000061',
#  'drive_sunset-3 0000000062',
#  'drive_sunset-3 0000000063',
#  'drive_sunset-3 0000000064',
#  'drive_sunset-3 0000000065',
#  'drive_sunset-3 0000000066',
#  'drive_sunset-3 0000000067',
#  'drive_sunset-3 0000000068',
#  'drive_sunset-3 0000000069',
#  'drive_sunset-3 0000000070',
#  'drive_sunset-3 0000000071',
#  'drive_sunset-3 0000000072',
#  'drive_sunset-3 0000000073',
#  'drive_sunset-3 0000000074',
#  'drive_sunset-3 0000000075',
#  'drive_sunset-3 0000000076',
#  'drive_sunset-3 0000000077',
#  'drive_sunset-3 0000000078',
#  'drive_sunset-3 0000000079',
#  'drive_sunset-3 0000000080',
#  'drive_sunset-3 0000000081',
#  'drive_sunset-3 0000000082',
#  'drive_sunset-3 0000000083',
#  'drive_sunset-3 0000000084',
#  'drive_sunset-3 0000000085',
#  'drive_sunset-3 0000000086',
#  'drive_sunset-3 0000000087',
#  'drive_sunset-3 0000000088',
#  'drive_sunset-3 0000000089',
#  'drive_sunset-3 0000000090',
#  'drive_sunset-3 0000000091',
#  'drive_sunset-3 0000000092',
#  'drive_sunset-3 0000000093',
#  'drive_sunset-3 0000000094',
#  'drive_sunset-3 0000000095',
#  'drive_sunset-3 0000000096',
#  'drive_sunset-3 0000000097',
#  'drive_sunset-3 0000000098',
#  'drive_sunset-3 0000000099',
#  'drive_sunset-3 0000000100',
#  'drive_sunset-3 0000000101',
#  'drive_sunset-3 0000000102',
#  'drive_sunset-3 0000000103',
#  'drive_sunset-3 0000000104',
#  'drive_sunset-3 0000000105',
#  'drive_sunset-3 0000000106',
#  'drive_sunset-3 0000000107',
#  'drive_sunset-3 0000000108',
#  'drive_sunset-3 0000000109',
#  'drive_sunset-3 0000000110',
#  'drive_sunset-3 0000000111',
#  'drive_sunset-3 0000000112',
#  'drive_sunset-3 0000000113',
#  'drive_sunset-3 0000000114',
#  'drive_sunset-3 0000000115',
#  'drive_noon-2 0000000001',
#  'drive_noon-2 0000000002',
#  'drive_noon-2 0000000003',
#  'drive_noon-2 0000000004',
#  'drive_noon-2 0000000005',
#  'drive_noon-2 0000000006',
#  'drive_noon-2 0000000007',
#  'drive_noon-2 0000000008',
#  'drive_noon-2 0000000009',
#  'drive_noon-2 0000000010',
#  'drive_noon-2 0000000011',
#  'drive_noon-2 0000000012',
#  'drive_noon-2 0000000013',
#  'drive_noon-2 0000000014',
#  'drive_noon-2 0000000015',
#  'drive_noon-2 0000000016',
#  'drive_noon-2 0000000017',
#  'drive_noon-2 0000000018',
#  'drive_noon-2 0000000019',
#  'drive_noon-2 0000000020',
#  'drive_noon-2 0000000021',
#  'drive_noon-2 0000000022',
#  'drive_noon-2 0000000023',
#  'drive_noon-2 0000000024',
#  'drive_noon-2 0000000025',
#  'drive_noon-2 0000000026',
#  'drive_noon-2 0000000027',
#  'drive_noon-2 0000000028',
#  'drive_noon-2 0000000029',
#  'drive_noon-2 0000000030',
#  'drive_noon-2 0000000031',
#  'drive_noon-2 0000000032',
#  'drive_noon-2 0000000033',
#  'drive_noon-2 0000000034',
#  'drive_noon-2 0000000035',
#  'drive_noon-2 0000000036',
#  'drive_noon-2 0000000037',
#  'drive_noon-2 0000000038',
#  'drive_noon-2 0000000039',
#  'drive_noon-2 0000000040',
#  'drive_noon-2 0000000041',
#  'drive_noon-2 0000000042',
#  'drive_noon-2 0000000043',
#  'drive_noon-2 0000000044',
#  'drive_noon-2 0000000045',
#  'drive_noon-2 0000000046',
#  'drive_noon-2 0000000047',
#  'drive_noon-2 0000000048',
#  'drive_noon-2 0000000049',
#  'drive_noon-2 0000000050',
#  'drive_noon-2 0000000051',
#  'drive_noon-2 0000000052',
#  'drive_noon-2 0000000053',
#  'drive_noon-2 0000000054',
#  'drive_noon-2 0000000055',
#  'drive_noon-2 0000000056',
#  'drive_noon-2 0000000057',
#  'drive_noon-2 0000000058',
#  'drive_noon-2 0000000059',
#  'drive_noon-2 0000000060',
#  'drive_noon-2 0000000061',
#  'drive_noon-2 0000000062',
#  'drive_noon-2 0000000063',
#  'drive_noon-2 0000000064',
#  'drive_noon-2 0000000065',
#  'drive_noon-2 0000000066',
#  'drive_noon-2 0000000067',
#  'drive_noon-2 0000000068',
#  'drive_noon-2 0000000069',
#  'drive_noon-2 0000000070',
#  'drive_noon-2 0000000071',
#  'drive_noon-2 0000000072',
#  'drive_noon-2 0000000073',
#  'drive_noon-2 0000000074',
#  'drive_noon-2 0000000075',
#  'drive_noon-2 0000000076',
#  'drive_noon-2 0000000077',
#  'drive_noon-2 0000000078',
#  'drive_noon-2 0000000079',
#  'drive_noon-2 0000000080',
#  'drive_noon-2 0000000081',
#  'drive_noon-2 0000000082',
#  'drive_noon-2 0000000083',
#  'drive_noon-2 0000000084',
#  'drive_noon-2 0000000085',
#  'drive_noon-2 0000000086',
#  'drive_noon-2 0000000087',
#  'drive_noon-2 0000000088',
#  'drive_noon-2 0000000089',
#  'drive_noon-2 0000000090',
#  'drive_noon-2 0000000091',
#  'drive_noon-2 0000000092',
#  'drive_noon-2 0000000093',
#  'drive_noon-2 0000000094',
#  'drive_noon-2 0000000095',
#  'drive_noon-2 0000000096',
#  'drive_noon-2 0000000097',
#  'drive_noon-2 0000000098',
#  'drive_noon-2 0000000099',
#  'drive_noon-2 0000000100',
#  'drive_noon-2 0000000101',
#  'drive_noon-2 0000000102',
#  'drive_noon-2 0000000103',
#  'drive_noon-2 0000000104',
#  'drive_noon-2 0000000105',
#  'drive_noon-2 0000000106',
#  'drive_noon-2 0000000107',
#  'drive_noon-2 0000000108',
#  'drive_noon-2 0000000109',
#  'drive_noon-2 0000000110',
#  'drive_noon-2 0000000111',
#  'drive_noon-2 0000000112',
#  'drive_noon-2 0000000113',
#  'drive_noon-2 0000000114',
#  'drive_noon-2 0000000115',
#  'drive_noon-2 0000000116',
#  'drive_noon-2 0000000117',
#  'drive_noon-2 0000000118',
#  'drive_noon-2 0000000001',
#  'drive_noon-2 0000000002',
#  'drive_noon-2 0000000003',
#  'drive_noon-2 0000000004',
#  'drive_noon-2 0000000005',
#  'drive_noon-2 0000000006',
#  'drive_noon-2 0000000007',
#  'drive_noon-2 0000000008',
#  'drive_noon-2 0000000009',
#  'drive_noon-2 0000000010',
#  'drive_noon-2 0000000011',
#  'drive_noon-2 0000000012',
#  'drive_noon-2 0000000013',
#  'drive_noon-2 0000000014',
#  'drive_noon-2 0000000015',
#  'drive_noon-2 0000000016',
#  'drive_noon-2 0000000017',
#  'drive_noon-2 0000000018',
#  'drive_noon-2 0000000019',
#  'drive_noon-2 0000000020',
#  'drive_noon-2 0000000021',
#  'drive_noon-2 0000000022',
#  'drive_noon-2 0000000023',
#  'drive_noon-2 0000000024',
#  'drive_noon-2 0000000025',
#  'drive_noon-2 0000000026',
#  'drive_noon-2 0000000027',
#  'drive_noon-2 0000000028',
#  'drive_noon-2 0000000029',
#  'drive_noon-2 0000000030',
#  'drive_noon-2 0000000031',
#  'drive_noon-2 0000000032',
#  'drive_noon-2 0000000033',
#  'drive_noon-2 0000000034',
#  'drive_noon-2 0000000035',
#  'drive_noon-2 0000000036',
#  'drive_noon-2 0000000037',
#  'drive_noon-2 0000000038',
#  'drive_noon-2 0000000039',
#  'drive_noon-2 0000000040',
#  'drive_noon-2 0000000041',
#  'drive_noon-2 0000000042',
#  'drive_noon-2 0000000043',
#  'drive_noon-2 0000000044',
#  'drive_noon-2 0000000045',
#  'drive_noon-2 0000000046',
#  'drive_noon-2 0000000047',
#  'drive_noon-2 0000000048',
#  'drive_noon-2 0000000049',
#  'drive_noon-2 0000000050',
#  'drive_noon-2 0000000051',
#  'drive_noon-2 0000000052',
#  'drive_noon-2 0000000053',
#  'drive_noon-2 0000000054',
#  'drive_noon-2 0000000055',
#  'drive_noon-2 0000000056',
#  'drive_noon-2 0000000057',
#  'drive_noon-2 0000000058',
#  'drive_noon-2 0000000059',
#  'drive_noon-2 0000000060',
#  'drive_noon-2 0000000061',
#  'drive_noon-2 0000000062',
#  'drive_noon-2 0000000063',
#  'drive_noon-2 0000000064',
#  'drive_noon-2 0000000065',
#  'drive_noon-2 0000000066',
#  'drive_noon-2 0000000067',
#  'drive_noon-2 0000000068',
#  'drive_noon-2 0000000069',
#  'drive_noon-2 0000000070',
#  'drive_noon-2 0000000071',
#  'drive_noon-2 0000000072',
#  'drive_noon-2 0000000073',
#  'drive_noon-2 0000000074',
#  'drive_noon-2 0000000075',
#  'drive_noon-2 0000000076',
#  'drive_noon-2 0000000077',
#  'drive_noon-2 0000000078',
#  'drive_noon-2 0000000079',
#  'drive_noon-2 0000000080',
#  'drive_noon-2 0000000081',
#  'drive_noon-2 0000000082',
#  'drive_noon-2 0000000083',
#  'drive_noon-2 0000000084',
#  'drive_noon-2 0000000085',
#  'drive_noon-2 0000000086',
#  'drive_noon-2 0000000087',
#  'drive_noon-2 0000000088',
#  'drive_noon-2 0000000089',
#  'drive_noon-2 0000000090',
#  'drive_noon-2 0000000091',
#  'drive_noon-2 0000000092',
#  'drive_noon-2 0000000093',
#  'drive_noon-2 0000000094',
#  'drive_noon-2 0000000095',
#  'drive_noon-2 0000000096',
#  'drive_noon-2 0000000097',
#  'drive_noon-2 0000000098',
#  'drive_noon-2 0000000099',
#  'drive_noon-2 0000000100',
#  'drive_noon-2 0000000101',
#  'drive_noon-2 0000000102',
#  'drive_noon-2 0000000103',
#  'drive_noon-2 0000000104',
#  'drive_noon-2 0000000105',
#  'drive_noon-2 0000000106',
#  'drive_noon-2 0000000107',
#  'drive_noon-2 0000000108',
#  'drive_noon-2 0000000001',
#  'drive_noon-2 0000000002',
#  'drive_noon-2 0000000003',
#  'drive_noon-2 0000000004',
#  'drive_noon-2 0000000005',
#  'drive_noon-2 0000000006',
#  'drive_noon-2 0000000007',
#  'drive_noon-2 0000000008',
#  'drive_noon-2 0000000009',
#  'drive_noon-2 0000000010',
#  'drive_noon-2 0000000011',
#  'drive_noon-2 0000000012',
#  'drive_noon-2 0000000013',
#  'drive_noon-2 0000000014',
#  'drive_noon-2 0000000015',
#  'drive_noon-2 0000000016',
#  'drive_noon-2 0000000017',
#  'drive_noon-2 0000000018',
#  'drive_noon-2 0000000019',
#  'drive_noon-2 0000000020',
#  'drive_noon-2 0000000021',
#  'drive_noon-2 0000000022',
#  'drive_noon-2 0000000023',
#  'drive_noon-2 0000000024',
#  'drive_noon-2 0000000025',
#  'drive_noon-2 0000000026',
#  'drive_noon-2 0000000027',
#  'drive_noon-2 0000000028',
#  'drive_noon-2 0000000029',
#  'drive_noon-2 0000000030',
#  'drive_noon-2 0000000031',
#  'drive_noon-2 0000000032',
#  'drive_noon-2 0000000033',
#  'drive_noon-2 0000000034',
#  'drive_noon-2 0000000035',
#  'drive_noon-2 0000000036',
#  'drive_noon-2 0000000037',
#  'drive_noon-2 0000000038',
#  'drive_noon-2 0000000039',
#  'drive_noon-2 0000000040',
#  'drive_noon-2 0000000041',
#  'drive_noon-2 0000000042',
#  'drive_noon-2 0000000043',
#  'drive_noon-2 0000000044',
#  'drive_noon-2 0000000045',
#  'drive_noon-2 0000000046',
#  'drive_noon-2 0000000047',
#  'drive_noon-2 0000000048',
#  'drive_noon-2 0000000049',
#  'drive_noon-2 0000000050',
#  'drive_noon-2 0000000051',
#  'drive_noon-2 0000000052',
#  'drive_noon-2 0000000053',
#  'drive_noon-2 0000000054',
#  'drive_noon-2 0000000055',
#  'drive_noon-2 0000000056',
#  'drive_noon-2 0000000057',
#  'drive_noon-2 0000000058',
#  'drive_noon-2 0000000059',
#  'drive_noon-2 0000000060',
#  'drive_noon-2 0000000061',
#  'drive_noon-2 0000000062',
#  'drive_noon-2 0000000063',
#  'drive_noon-2 0000000064',
#  'drive_noon-2 0000000065',
#  'drive_noon-2 0000000066',
#  'drive_noon-2 0000000067',
#  'drive_noon-2 0000000068',
#  'drive_noon-2 0000000069',
#  'drive_noon-2 0000000070',
#  'drive_noon-2 0000000071',
#  'drive_noon-2 0000000072',
#  'drive_noon-2 0000000073',
#  'drive_noon-2 0000000074',
#  'drive_noon-2 0000000075',
#  'drive_noon-2 0000000076',
#  'drive_noon-2 0000000077',
#  'drive_noon-2 0000000078',
#  'drive_noon-2 0000000079',
#  'drive_noon-2 0000000080',
#  'drive_noon-2 0000000081',
#  'drive_noon-2 0000000082',
#  'drive_noon-2 0000000083',
#  'drive_noon-2 0000000084',
#  'drive_noon-2 0000000085',
#  'drive_noon-2 0000000086',
#  'drive_noon-2 0000000087',
#  'drive_noon-2 0000000088',
#  'drive_noon-2 0000000089',
#  ...]

# %%
file=file_names[0]

# %%
dataset=file.split(" ")[0]

# %%
imname=file.split(" ")[1]

# %%
im_fname=base_path + "/"+dataset+"/"+imname+"-fseg.png"

image = skimage.io.imread(im_fname)


# Run detection
#image=cv2.resize(image,(192,192))


# Visualize results

# %%
import cv2

color_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 

import matplotlib.pyplot as plt
fig, axes = plt.subplots(figsize=(6, 6))
axes.imshow(color_img)
axes.axis('off')
plt.show()

# %%
#train.txtを読んだ方がいいかも
